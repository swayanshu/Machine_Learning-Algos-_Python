# %%
https://github.com/trafferty/ipython-opencv-notebooks/tree/master/notebooks

import matplotlib.pyplot as plt

# %%
import cv2
import numpy as np

# %%
img = cv2.imread('panda.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img
# Out:
# array([[ 87,  88,  89, ...,  81,  62, 111],
#        [ 91,  91,  91, ...,  92,  66, 120],
#        [ 95,  95,  94, ...,  80,  46, 103],
#        ...,
#        [210, 137, 104, ..., 105,  60,  26],
#        [192, 127,  77, ...,  63,  57,  23],
#        [191, 144, 113, ..., 124,  37,  27]], dtype=uint8)

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.plot([200,300,400],[100,200,300],'c', linewidth=5)
plt.show()

# %%
cv2.imwrite('watchgray.png',img)
# Out:
# True

# %% [markdown]
# # Drawing and Writing on Image OpenCV Python

# %%
import numpy as np
import cv2

img = cv2.imread('panda.jpg',cv2.IMREAD_COLOR)
cv2.line(img,(0,0),(200,300),(255,255,255),50)
cv2.rectangle(img,(500,250),(1000,500),(0,0,255),15)
cv2.circle(img,(447,63), 63, (0,255,0), -1)
pts = np.array([[100,50],[200,300],[700,200],[500,100]], np.int32)
pts = pts.reshape((-1,1,2))
cv2.polylines(img, [pts], True, (0,255,255), 3)
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,'OpenCV Tuts!',(10,500), font, 6, (200,255,155), 13, cv2.LINE_AA)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
#import matplotlib library
import matplotlib.pyplot as plt
#importing time library for speed comparisons of both classifiers
import time
# %matplotlib inline

# %%
def convertToRGB(img): 
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
#load test iamge
test1 = cv2.imread('panda.jpg')
#convert the test image to gray image as opencv face detector expects gray images
gray_img = cv2.cvtColor(test1, cv2.COLOR_BGR2GRAY)

# %%
#if you have matplotlib installed then
plt.imshow(gray_img, cmap='gray')

# %%
#load cascade classifier training file for haarcascade
haar_face_cascade = cv2.CascadeClassifier('data/haarcascade_frontalface_alt.xml')

# %%
import numpy as np
import cv2 as cv

# %%
import matplotlib.pyplot as plt

# %%
#load test iamge
test1 = cv.imread('panda.jpg')
#convert the test image to gray image as opencv face detector expects gray images
gray_img = cv.cvtColor(test1, cv.COLOR_BGR2GRAY)

# %%
#if you have matplotlib installed then
plt.imshow(gray_img, cmap='gray')
